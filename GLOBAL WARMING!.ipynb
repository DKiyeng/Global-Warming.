# %% [markdown]
# Global warming is the long-term heating of Earth’s climate system due to human activities, primarily fossil fuel burning, which increases heat-trapping greenhouse gas levels in Earth’s atmosphere. The term is frequently used interchangeably with the term climate change, though the latter refers to both human- and naturally produced warming and the effects it has on our planet. It is most commonly measured as the average increase in Earth’s global surface temperature.
#
# Climate change on the other hand is a long-term change in the average weather patterns that have come to define Earth’s local, regional and global climates.
#
# Climate change denial, or global warming denial is denial or unwarranted doubt that contradicts the scientific consensus on climate change, including the extent to which it is caused by humans, its effects on nature and human society, or the potential of adaptation to global warming by human actions.

# %% [markdown]
# I was compelled to analyze Nairobi's (Lon: 36.8172449 Lat: -1.2832533) surface temperature for a period of 20 years (2000-2020). The temperature data used was extracted from ESA's EO4SD Climate Resilience platform. I will try to analyze this data to establish average daily surface temperature using Jupyter notebooks.

# %%
#import pandas and mathplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %%
pwd
# Out:
# 'C:\\Users\\User'

# %%
#read csv file.
temp = pd.read_csv("Nairobi.csv")

# %%
temp.columns
# Out:
# Index(['Year', 'Average Daily Temp(K)'], dtype='object')

# %%
#Data summary
temp.head()
# Out:
#    Year  Average Daily Temp(K)
# 0  2000             291.928549
# 1  2001             291.610277
# 2  2002             291.833458
# 3  2003             292.003208
# 4  2004             292.075090

# %%
temp
# Out:
#     Year  Average Daily Temp(K)
# 0   2000             291.928549
# 1   2001             291.610277
# 2   2002             291.833458
# 3   2003             292.003208
# 4   2004             292.075090
# 5   2005             292.188301
# 6   2006             292.111679
# 7   2007             292.117082
# 8   2008             292.045230
# 9   2009             292.581666
# 10  2010             292.155551
# 11  2011             292.567101
# 12  2012             292.204921
# 13  2013             291.979159
# 14  2014             292.283496
# 15  2015             292.615907
# 16  2016             292.449828
# 17  2017             292.985603
# 18  2018             292.040967
# 19  2019             292.972458
# 20  2020             292.385924

# %%
#2000 to 2010 raw data.
# Read image

Image(filename='2000_2010.png')

# %%
#2010 to 2020 raw data.
# Read image

Image(filename='2010_2020.png')

# %%
#Plot a graph of the average daily surface temperature against the year.
plt.figure(figsize=(12,6))
plt.bar(x=temp['Year'],
 
        height=temp['Average Daily Temp(K)'])

plt.xticks(rotation=45)
plt.ylabel('Average Daily Tempearture (K)')
plt.xlabel('Year')
plt.ylim((290,293.5))
# Out:
# (290, 293.5)

# %% [markdown]
# From 2000 to 2010 data, the daily temperature data for Nairobi was quite stable though steadily rising as shown by the average daily temperature and almost predictable. On the other hand, 2010 to 2020 data was a bit chaotic with a general rise in average daily temperature. 2017 and 2019 recorded the highest average daily temperature of 293°K.
#
# According to NASA's Goddard Institute for Space Studies (GISS) Global temperature statistics, nineteen of the warmest years have occurred since 2000, with the exception of 1998. The year 2020 tied with 2016 for the warmest year on record since record-keeping began in 1880.
